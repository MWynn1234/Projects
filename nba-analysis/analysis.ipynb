# %%
df.groupby('PTS_TYPE')['SHOT_RESULT'].mean().plot(kind='bar')
plt.title("2PT vs 3PT Shooting %")
plt.ylabel("Shooting Percentage")
plt.savefig("visuals/shot_type.png")
plt.show()

# %%
df['player_name'].value_counts().head(10).plot(kind='bar')
plt.title("Top Players by Shot Attempts")
plt.xlabel("Player")
plt.ylabel("Attempts")
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig("visuals/top_players.png")
plt.show()

# %%
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('data/shot_logs.csv')

# Cleaning step
df['SHOT_RESULT'] = df['SHOT_RESULT'].map({
    'made': 1,
    'missed': 0
})

# %%
df.groupby(pd.cut(df['CLOSE_DEF_DIST'], bins=5))['SHOT_RESULT'].mean()
# Out:
# CLOSE_DEF_DIST
# (-0.0532, 10.64]    0.451248
# (10.64, 21.28]      0.472581
# (21.28, 31.92]      0.690476
# (31.92, 42.56]      1.000000
# (42.56, 53.2]       1.000000
# Name: SHOT_RESULT, dtype: float64

# %%
df.groupby('PTS_TYPE')['SHOT_RESULT'].mean()
# Out:
# PTS_TYPE
# 2    0.488357
# 3    0.351516
# Name: SHOT_RESULT, dtype: float64

# %%
df.groupby('SHOT_DIST')['SHOT_RESULT'].mean()
# Out:
# SHOT_DIST
# 0.0     0.500000
# 0.1     0.559322
# 0.2     0.640000
# 0.3     0.676829
# 0.4     0.645631
#           ...
# 46.2    0.000000
# 46.3    0.000000
# 46.7    0.000000
# 46.9    0.000000
# 47.2    1.000000
# Name: SHOT_RESULT, Length: 448, dtype: float64

# %%
player_stats = df.groupby('player_name').agg(
    attempts=('SHOT_RESULT', 'count'),
    shooting_pct=('SHOT_RESULT', 'mean')
)

player_stats = player_stats[player_stats['attempts'] > 100]

player_stats.sort_values(by='shooting_pct', ascending=False).head(10)
# Out:
#                 attempts  shooting_pct
# player_name
# deandre jordan       393      0.712468
# tyson chandler       340      0.676471
# rudy gobert          267      0.625468
# james johnson        311      0.614148
# ed davis             350      0.602857
# alexis ajinca        211      0.597156
# mason plumlee        403      0.585608
# john henson          241      0.580913
# chris andersen       136      0.580882
# amir johnson         402      0.579602

# %%
df = pd.read_csv('data/shot_logs.csv')

df['SHOT_RESULT'] = df['SHOT_RESULT'].map({
    'made': 1,
    'missed': 0
})

df['SHOT_RESULT'].dtype
# Out:
# dtype('int64')

# %%
import pandas as pd

df = pd.read_csv('data/shot_logs.csv')

df['SHOT_RESULT'] = df['SHOT_RESULT'].map({
    'made': 1,
    'missed': 0
})

df[['SHOT_RESULT']].head()
# Out:
#    SHOT_RESULT
# 0            1
# 1            0
# 2            0
# 3            0
# 4            0

# %%
pd.read_csv('data/shot_logs.csv')['SHOT_RESULT'].unique()
# Out:
# <StringArray>
# ['made', 'missed']
# Length: 2, dtype: str

# %%
df['SHOT_RESULT'] = df['SHOT_RESULT'].astype(str).str.strip().str.lower()

df['SHOT_RESULT'] = df['SHOT_RESULT'].map({
    'made': 1,
    'missed': 0
})

# %%
df.drop_duplicates(inplace=True)
df.isnull().sum()
# Out:
# GAME_ID                          0
# MATCHUP                          0
# LOCATION                         0
# W                                0
# FINAL_MARGIN                     0
# SHOT_NUMBER                      0
# PERIOD                           0
# GAME_CLOCK                       0
# SHOT_CLOCK                    5567
# DRIBBLES                         0
# TOUCH_TIME                       0
# SHOT_DIST                        0
# PTS_TYPE                         0
# SHOT_RESULT                      0
# CLOSEST_DEFENDER                 0
# CLOSEST_DEFENDER_PLAYER_ID       0
# CLOSE_DEF_DIST                   0
# FGM                              0
# PTS                              0
# player_name                      0
# player_id                        0
# dtype: int64

# %%
df['SHOT_RESULT'].unique()
# Out:
# <StringArray>
# ['made', 'missed']
# Length: 2, dtype: str

# %%
df.columns
# Out:
# Index(['GAME_ID', 'MATCHUP', 'LOCATION', 'W', 'FINAL_MARGIN', 'SHOT_NUMBER',
#        'PERIOD', 'GAME_CLOCK', 'SHOT_CLOCK', 'DRIBBLES', 'TOUCH_TIME',
#        'SHOT_DIST', 'PTS_TYPE', 'SHOT_RESULT', 'CLOSEST_DEFENDER',
#        'CLOSEST_DEFENDER_PLAYER_ID', 'CLOSE_DEF_DIST', 'FGM', 'PTS',
#        'player_name', 'player_id'],
#       dtype='str')

# %%
import pandas as pd

df = pd.read_csv('data/shot_logs.csv')

df.head()
# Out:
#     GAME_ID                   MATCHUP LOCATION  W  FINAL_MARGIN  SHOT_NUMBER  \
# 0  21400899  MAR 04, 2015 - CHA @ BKN        A  W            24            1
# 1  21400899  MAR 04, 2015 - CHA @ BKN        A  W            24            2
# 2  21400899  MAR 04, 2015 - CHA @ BKN        A  W            24            3
# 3  21400899  MAR 04, 2015 - CHA @ BKN        A  W            24            4
# 4  21400899  MAR 04, 2015 - CHA @ BKN        A  W            24            5
#
#    PERIOD GAME_CLOCK  SHOT_CLOCK  DRIBBLES  ...  SHOT_DIST  PTS_TYPE  \
# 0       1       1:09        10.8         2  ...        7.7         2
# 1       1       0:14         3.4         0  ...       28.2         3
# 2       1       0:00         NaN         3  ...       10.1         2
# 3       2      11:47        10.3         2  ...       17.2         2
# 4       2      10:34        10.9         2  ...        3.7         2
#
#    SHOT_RESULT   CLOSEST_DEFENDER CLOSEST_DEFENDER_PLAYER_ID  CLOSE_DEF_DIST  \
# ...
